# %%
# import PySimpleGUI as sg
# import matplotlib.pyplot as plt
# from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
   
# year = [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010]
# unemployment_rate = [9.8,12,8,7.2,6.9,7,6.5,6.2,5.5,6.3]
  
# def create_bar_graph(year, unemployment_rate):
#     plt.figure(figsize =(10, 7))
#     plt.bar(year, unemployment_rate, color='red', width=0.4)
#     plt.title('Unemployment Rate Vs Year', fontsize=14)
#     plt.xlabel('Year', fontsize=14)
#     plt.ylabel('Unemployment Rate', fontsize=14)
#     return plt.gcf()

# layout = [[sg.Text('Bar Graph')],
#           [sg.Canvas(size=(900, 900), key='-CANVAS-')],
#           [sg.Exit()]]

# def draw_figure(canvas, figure):
#     figure_canvas_agg = FigureCanvasTkAgg(figure, canvas)
#     figure_canvas_agg.draw()
#     figure_canvas_agg.get_tk_widget().pack(side='top', fill='both', expand=1)
#     return figure_canvas_agg


# window = sg.Window('PySimpleGUI + MatPlotLib Bar Graphs', layout, finalize=True, element_justification='center')

# draw_figure(window['-CANVAS-'].TKCanvas, create_bar_graph(year, unemployment_rate))

# while True:
#     event, values = window.read()
#     if event == sg.WIN_CLOSED or event == 'Exit':
#         break

# window.close()

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
nodes = pd.read_csv('F:\FCIS\socialNetwork_Project\metadata_primaryschool_Nodes.csv')

# %%
g = nx.Graph()
for x in range(len(nodes['ID'])):
    g.add_node(nodes['ID'][x])

# %%
g.nodes()
# Out:
# NodeView((1426, 1427, 1428, 1429, 1430, 1431, 1434, 1435, 1437, 1439, 1441, 1443, 1451, 1452, 1453, 1457, 1458, 1459, 1461, 1465, 1468, 1471, 1475, 1477, 1479, 1480, 1482, 1483, 1486, 1489, 1493, 1495, 1498, 1500, 1501, 1502, 1503, 1504, 1511, 1516, 1519, 1520, 1521, 1522, 1524, 1525, 1528, 1532, 1533, 1538, 1539, 1545, 1546, 1548, 1549, 1551, 1552, 1555, 1558, 1560, 1562, 1563, 1564, 1567, 1570, 1572, 1574, 1578, 1579, 1580, 1585, 1592, 1594, 1601, 1603, 1604, 1606, 1609, 1613, 1616, 1617, 1618, 1625, 1628, 1630, 1632, 1637, 1641, 1643, 1647, 1648, 1649, 1650, 1653, 1656, 1661, 1663, 1664, 1665, 1666, 1668, 1670, 1673, 1674, 1675, 1680, 1681, 1682, 1684, 1685, 1687, 1688, 1695, 1696, 1697, 1698, 1700, 1702, 1704, 1705, 1706, 1707, 1708, 1709, 1710, 1711, 1712, 1713, 1714, 1715, 1718, 1719, 1720, 1722, 1723, 1727, 1730, 1731, 1732, 1735, 1737, 1738, 1739, 1741, 1743, 1744, 1745, 1746, 1748, 1749, 1750, 1751, 1752, 1753, 1757, 1759, 1760, 1761, 1763, 1764, 1765, 1766, 1767, 1768, 1770, 1772, 1774, 1775, 1778, 1779, 1780, 1782, 1783, 1787, 1789, 1790, 1792, 1795, 1796, 1797, 1798, 1799, 1800, 1801, 1802, 1803, 1805, 1807, 1809, 1815, 1818, 1819, 1820, 1821, 1822, 1824, 1831, 1833, 1835, 1836, 1837, 1838, 1843, 1847, 1851, 1852, 1854, 1855, 1857, 1858, 1859, 1861, 1863, 1865, 1866, 1872, 1877, 1880, 1883, 1885, 1887, 1888, 1889, 1890, 1892, 1895, 1897, 1898, 1902, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1916, 1917, 1919, 1920, 1922))

# %%
edges = pd.read_csv('F:\FCIS\socialNetwork_Project\primaryschool_Edges.csv')

# %%
edges
# Out:
#         Source  Target
# 0         1558    1567
# 1         1560    1570
# 2         1567    1574
# 3         1632    1818
# 4         1632    1866
# ...        ...     ...
# 125768    1752    1783
# 125769    1752    1789
# 125770    1775    1798
# 125771    1783    1796
# 125772    1913    1922
#
# [125773 rows x 2 columns]

# %%
for x in range(len(edges['Source'])):
    g.add_edge(edges['Source'][x], edges['Target'][x])

# %%
nx.draw(g)

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx(g)
plt.show()

# %%
import PySimpleGUI as sg
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
   
  
def create_bar_graph():
    plt.figure(figsize =(10, 7))
    nx.draw_networkx(g)
    return plt.gcf()

layout = [[sg.Text('Bar Graph')],
          [sg.Canvas(size=(900, 900), key='-CANVAS-')],
          [sg.Exit()]]

def draw_figure(canvas, figure):
    figure_canvas_agg = FigureCanvasTkAgg(figure, canvas)
    figure_canvas_agg.draw()
    figure_canvas_agg.get_tk_widget().pack(side='top', fill='both', expand=1)
    return figure_canvas_agg


window = sg.Window('PySimpleGUI + MatPlotLib Bar Graphs', layout, finalize=True, element_justification='center')

draw_figure(window['-CANVAS-'].TKCanvas, create_bar_graph())

while True:
    event, values = window.read()
    if event == sg.WIN_CLOSED or event == 'Exit':
        break

window.close()
